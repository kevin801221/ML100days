# %% [markdown]
# # [作業目標]
# - 利用範例的創建方式, 創建一組資料, 並練習如何取出最大值

# %% [markdown]
# # [作業重點]
# - 練習創立 DataFrame (In[2])
# - 如何取出口數最多的國家 (In[3], Out[3])

# %% [markdown]
# ## 練習時間
# 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果
#
# 請嘗試想像一個你需要的資料結構 (裡面的值可以是隨機的)，然後用上述的方法把它變成 pandas DataFrame
#
# #### Ex: 想像一個 dataframe 有兩個欄位，一個是國家，一個是人口，求人口數最多的國家
#
# ### Hints: [隨機產生數值](https://blog.csdn.net/christianashannon/article/details/78867204)

# %%
import pandas as pd
import numpy as np

# %%
data = {'國家':["Taiwan","America","Japan","Thailan"] ,
        '人口':["51515","22005","85685","12003"] }
data = pd.DataFrame(data)
data
# Out:
#         國家     人口
# 0   Taiwan  51515
# 1  America  22005
# 2    Japan  85685
# 3  Thailan  12003

# %%
data = {'國家':["Taiwan","America","Japan","Thailan","Singapore"] ,
        '人口':np.random.randint(12000,size=5) }
data = pd.DataFrame(data)
data.max()
# Out:
# 國家    Thailan
# 人口      11981
# dtype: object

# %% [markdown]
# ## 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ### Hints: 使用 [Request](https://blog.gtwang.org/programming/python-requests-module-tutorial/) 抓取資料
# ### Hints: [字串分割](http://www.runoob.com/python/att-string-split.html)
# ### Hints: 例外處理: [Try-Except](https://pydoing.blogspot.com/2011/01/python-try.html)

# %% [markdown]
# # [作業目標]
# - 試著讀取網頁上的圖片連結清單, 再以清單中網址讀取圖片

# %% [markdown]
# # [作業重點]
# - 從網頁上讀取連結清單 (In[1], In[2])
# - 從清單網址讀取圖片 (In[6]~In[9], Out[6]~Out[9])

# %%
## 假如我們不想把資料載到自己的電腦裡?
# 把連結填入
#我好懶~
target_url = "https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt"

# %%
import requests
response = requests.get(target_url)
data = response.text

# 用 request 傳送回來的資料不會認得斷行符號
print(len(data))
data[0:100]
# Out:
# 784594
# 'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238\thttp://farm2'

# %%
# 找到換行符號，用該符號做字串分割後，把它拿掉
split_tag = "\t"
data = data.split(split_tag)
print(len(data))
data[0:800]
# Out:
# 9996
# ['n00015388_157',
#  'http://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238',
#  'http://farm2.static.flickr.com/1005/3352960681_37b9c1d27b.jpg\nn00015388_304',
#  'http://farm1.static.flickr.com/27/51009336_a9663af3dd.jpg\nn00015388_327',
#  'http://farm4.static.flickr.com/3025/2444687979_bf7bc8df21.jpg\nn00015388_355',
#  'http://img100.imageshack.us/img100/3253/forrest004fs9.jpg\nn00015388_373',
#  'http://img172.imageshack.us/img172/4606/napo03072en9.jpg\nn00015388_379',
#  'http://fotootjesvanannelies.web-log.nl/olifantfotootjes/images/2008/06/04/img_8870.jpg\nn00015388_388',
#  'http://www.deweekkrant.nl/images/library/pictures/4f/2e/a5/cf/2_3d81b762a5e8a345bbb1f0884fab2e9762146129.jpg\nn00015388_442',
#  'http://www.porschemania.it/discus/messages/815/102099.jpg\nn00015388_474',
#  'http://farm1.static.flickr.com/72/225029238_805b0937ca.jpg\nn00015388_514',
#  'http://farm2.static.flickr.com/1128/1432436038_6c131f1bb0.jpg\nn00015388_671',
# ...

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
import pandas as pd

    
df = pd.DataFrame(data)
df.head()
# Out:
#                                                    0
# 0                                      n00015388_157
# 1  http://farm1.static.flickr.com/145/430300483_2...
# 2  http://farm2.static.flickr.com/1005/3352960681...
# 3  http://farm1.static.flickr.com/27/51009336_a96...
# 4  http://farm4.static.flickr.com/3025/2444687979...

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# 請用 df.loc[...] 得到第一筆資料的連結
first_link = df.loc["http://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238"]  #df.loc["你想看的row名稱"]

response = requests.get(first_link)
img = Image.open(BytesIO(response.content))

# Convert img to numpy array

plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [http://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-9308c212dd87> in <module>()
#       5
#       6 # 請用 df.loc[...] 得到第一筆資料的連結
# ...
